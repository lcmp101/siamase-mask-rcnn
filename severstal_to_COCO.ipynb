# %%
# !pip install -Uqqq pycocotools

# %%
# !pip install tqdm

# %%
import cv2
import itertools
import json
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import random
from pycocotools.coco import COCO

from pathlib import Path
from PIL import Image

from itertools import groupby
from skimage import io
from sklearn.model_selection import train_test_split
from tqdm import tqdm

import pycocotools.mask as mask_util

# %% [markdown]
# Lectura del fichero csv

# %%
df = pd.read_csv('/data/lmp/code/siamese-mask-rcnn/data/severstal-steel-defect-detection/train.csv')
df.head()
# Out:
#          ImageId  ClassId                                      EncodedPixels
# 0  0002cc93b.jpg        1  29102 12 29346 24 29602 24 29858 24 30114 24 3...
# 1  0007a71bf.jpg        3  18661 28 18863 82 19091 110 19347 110 19603 11...
# 2  000a4bcdd.jpg        1  37607 3 37858 8 38108 14 38359 20 38610 25 388...
# 3  000f6bf48.jpg        4  131973 1 132228 4 132483 6 132738 8 132993 11 ...
# 4  0014fce06.jpg        3  229501 11 229741 33 229981 55 230221 77 230468...

# %%
def rle_decode(mask_rle, shape):
    """
    Decodes run-length encoded segmentation mask string into 2d array

    Parameters
    ----------
    :param rle_mask (str): Run-length encoded segmentation mask string.
    :param shape (tuple): (height, width) of array to return
    :return mask [numpy.ndarray of shape (height, width)]: Decoded 2d segmentation mask
    """
    # Splits the RLE string into a list of string by whitespaces.
    s = mask_rle.split()

    # This creates two numpy arrays, one with the RLE starts and one with their respective lengths
    starts, lengths = [np.asarray(x, dtype=int) for x in (s[0:][::2], s[1:][::2])]

    # To obtain the end point we need to substract 1 to the length or start because the initial point counts.
    starts -= 1
    ends = starts + lengths

    # Create a 1D array of size H*W of zeros
    mask = np.zeros(shape[0]*shape[1], dtype=np.uint8)

    # Fill this array with ones in the positions where there is a mask using the RLE information
    for start, end in zip(starts, ends):
        mask[start:end] = 1

    # Reshape the 1D array into a 2D array so we can finally get the binary 2D mask.
    mask = mask.reshape(shape)
    return mask.T


def binary_mask_to_rle(binary_mask):
    """
    Checkout: https://cocodataset.org/#format-results
    :param mask [numpy.ndarray of shape (height, width)]: Decoded 2d segmentation mask

    This function returns the following dictionary:
    {
        "counts": encoded mask suggested by the official COCO dataset webpage.
        "size": the size of the input mask/image
    }
    """
    # Create dictionary for the segmentation key in the COCO dataset
    rle = {'counts': [], 'size': list(binary_mask.shape)}
    # We need to convert it to a Fortran array
    binary_mask_fortran = np.asfortranarray(binary_mask)
    # Encode the mask as specified by the official COCO format
    encoded_mask = mask_util.encode(binary_mask_fortran)
    # We must decode the byte encoded string or otherwise we cannot save it as a JSON file
    rle["counts"] = encoded_mask["counts"].decode()
    return rle

# %%
rle = df.loc[0, 'EncodedPixels']
#print(rle)
plt.imshow(rle_decode(rle, (1600, 256)))

# %% [markdown]
# Creación del dataset a formato COCO json

# %%
def create_coco_format_json(data_frame, classes, filepaths):
    """
    This function creates a COCO dataset.
    :param data_frame: pandas dataframe with an "id" column.
    :param classes: list of strings where each string is a class.
    :param filepaths: a list of strings containing all images paths
    :return dataset_coco_format: COCO dataset (JSON).
    """
    images = []
    annotations = []
    categories = []
    count = 0

    # Creates a categories list, i.e: [{'id': 0, 'name': 'a'}, {'id': 1, 'name': 'b'}, {'id': 2, 'name': 'c'}]
    for idx, class_ in enumerate(classes):
        categories.append(
            {
                "id": class_,
                "name": f'class_{class_}'
            }
        )

    # Iterate over image filepaths
    for filepath in tqdm(filepaths):
        # Get the image id, e.g: "10044"
        #print(filepath)
        file_id = filepath.split("/")[-1]
        #print(file_id)
        # Get the image height, e.g: 360 (px)
        height = 1600
        # Get the image width, e.g: 310 (px)
        width = 256
        # One image has many annotations associated to it (1 for each class), get a list with the indices.
        ids = data_frame.index[data_frame['ImageId'] == file_id].tolist()
        #print(ids)
        # Get filename
        file_name = filepath.split("/")[-1]


        if (len(ids) > 0):
            # Adding images which has annotations
            images.append(
                {
                    "id": file_id,
                    "width": width,
                    "height": height,
                    "file_name": file_name
                }
            )
            for idx in ids:
                # Convert the RLE string into a numpy array binary mask
                mk = rle_decode(data_frame.iloc[idx]['EncodedPixels'], (height, width))
                ys, xs = np.where(mk)
                x1, x2 = min(xs), max(xs)
                y1, y2 = min(ys), max(ys)
                """
                Contours can be explained simply as a curve joining all the continuous points (along the boundary),
                having same color or intensity. The function retrieves contours from the binary image using the
                algorithm specified in the function. One RLE segmentation for a single class may have disconnected
                shapes, like "spots". We will iterate over these "spots" thus creating a new image for each spot.
                This image will be temporary, it will help us create annotations for each of these "spots".
                """
                contours, hierarchy = cv2.findContours(mk,cv2.RETR_CCOMP,cv2.CHAIN_APPROX_NONE)

                for id_, contour in enumerate(contours):
                    # Image with 3 channels where H and W remain the same.
                    mask_image = np.zeros((mk.shape[0], mk.shape[1], 3),  np.uint8)
                    # This function takes the image and fills the contour inside it.
                    cv2.drawContours(mask_image, [contour], -1, (255,255,255), thickness=cv2.FILLED)
                    mask_image = cv2.cvtColor(mask_image, cv2.COLOR_BGR2GRAY)
                    mask_image_bool = np.array(mask_image, dtype=bool).astype(np.uint8)
                    ys, xs = np.where(mask_image_bool)
                    x1, x2 = min(xs), max(xs)
                    y1, y2 = min(ys), max(ys)
                    enc = binary_mask_to_rle(mask_image_bool)
                    seg = {
                        'segmentation': enc,
                        'bbox': [int(x1), int(y1), int(x2-x1+1), int(y2-y1+1)],
                        'area': int(np.sum(mask_image_bool)),
                        'image_id':file_id,
                        'category_id':int(data_frame.iloc[idx]['ClassId']),
                        'iscrowd':0,
                        'id': count
                    }
                    annotations.append(seg)
                    count +=1


    # Create the dataset
    dataset_coco_format = {
        "categories": categories,
        "images": images,
        "annotations": annotations,
    }

    return dataset_coco_format


def sep():
    print("-"*100)

# %%
r = pd.read_csv('/data/lmp/code/siamese-mask-rcnn/data/severstal-steel-defect-detection/csv files/test3.csv')

# %%
DATASET_PATH = "/data/lmp/code/siamese-mask-rcnn/data/severstal-steel-defect-detection/prueba/test3"

# %%
# Set classes
classes = df["ClassId"].unique().tolist()

# %%
filepaths = list()

for (dirpath, dirnames, filenames) in os.walk(DATASET_PATH):
    filepaths += [os.path.join(dirpath, file) for file in filenames if file.endswith(".jpg")]

#print(filepaths)

# %%
# Create COCO Datasets
g_json = create_coco_format_json(r, classes, filepaths)
# Out:
# 100%|██████████| 666/666 [00:23<00:00, 27.84it/s]

# %%
g_json['categories']
# Out:
# [{'id': 1, 'name': 'class_1'},
#  {'id': 3, 'name': 'class_3'},
#  {'id': 4, 'name': 'class_4'},
#  {'id': 2, 'name': 'class_2'}]

# %%
g_json['annotations']
# Out:
# [{'segmentation': {'counts': 'cjY5k0^6o0F9G:TM]NiNm1WOK_OiM?o5]O\\1M3N2O100O100000lJ1W2OeM9W2FgMb0T2^OhMk0S2UOgMV1T2jNdMc1W2]NaMQ2Y2TNZMZ2n0PNgN0I^2j0cNlNn24^VP7',
#    'size': [256, 1600]},
#   'bbox': [679, 0, 24, 254],
#   'area': 4462,
#   'image_id': '277e3727f.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 0},
#  {'segmentation': {'counts': 'doo9:T7b0^Ob0^Ob0^Ob0]Oc0^Ob0^Ob0^Ob0^Ob0^Ob0F:\\NX4e1gK\\NX4d1hK\\NX4e1gK\\NX4e1gK[NY4f1fK[NY4e1fK]NY4d1fK\\NZ4e1eK\\NZ4d1fK\\NZ4e1eK\\NZ4e1eK[N[4e1dK]N[4d1dK\\N\\4e1cK\\N\\4e1cK\\N\\4d1dK\\N\\4e1bK]N]4h1^KXNb4P2VKQNi4c201O001O1O001O001O001O001O0000001O0000000000001O0000000000001N10000O10000O2ULfMn1Z2lMUOk0k0oNHc09WO9=Ydn0',
#    'size': [256, 1600]},
#   'bbox': [1279, 38, 198, 218],
#   'area': 36682,
#   'image_id': '46dfd5be4.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 1},
#  {'segmentation': {'counts': 'P`\\:2n73M3M2N1O1O1O001O001O001O00001O001O001O001O00001O001O001O00001O001O001O001O00001O001O001O00001O001O001O0010O010O010O010O10O010O0100O0100O010O0100O010O010O10O01N101O001N2O001O0O2O1O001N101O001N2O001O0O2OToY1',
#    'size': [256, 1600]},
#   'bbox': [1330, 0, 102, 47],
#   'area': 2501,
#   'image_id': '46dfd5be4.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 2},
#  {'segmentation': {'counts': 'cok33k75K4L4N1O001N1L5M20O101O0000000O2O0000hP_8',
#    'size': [256, 1600]},
#   'bbox': [495, 230, 20, 26],
#   'area': 395,
#   'image_id': '43c6a30fa.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 3},
#  {'segmentation': {'counts': '_fg37g7=C5K4N2M100O100OO2L3N3M2MPjd8',
#    'size': [256, 1600]},
#   'bbox': [478, 196, 14, 36],
#   'area': 371,
#   'image_id': '43c6a30fa.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 4},
#  {'segmentation': {'counts': 'gUd3;a76K5L4M1O1O1O11O2N2N1O2N1EkHIW72?L[jg8',
#    'size': [256, 1600]},
#   'bbox': [464, 170, 16, 30],
#   'area': 340,
#   'image_id': '43c6a30fa.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 5},
#  {'segmentation': {'counts': 'l\\S4;]7;H6H8H8K500O100O10N1O2O1N3M3M3M3L4LfkW8',
#    'size': [256, 1600]},
#   'bbox': [525, 125, 19, 53],
#   'area': 756,
#   'image_id': '43c6a30fa.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 6},
#  {'segmentation': {'counts': 'TdW34j78H8H5K21O001O1O001O1O1O001N2N1NmHHc66XI6h6BTIj0j67M1O1O001O12M4K6G8^O_SQ9',
#    'size': [256, 1600]},
#   'bbox': [414, 124, 29, 61],
#   'area': 771,
#   'image_id': '43c6a30fa.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id':
jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 12},
#  {'segmentation': {'counts': 'QXT7P4P4o3QL000001O000000000O10001O000000000^Ob0lNT1lNU1kNT1mNS1lNT1lNPaU5',
#    'size': [256, 1600]},
#   'bbox': [913, 1, 25, 255],
#   'area': 5318,
#   'image_id': 'fe01b0ce0.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 13},
#  {'segmentation': {'counts': 'PXl6P4P4o3QL00000000QW3o0PfLP2PNP2PNPR^5',
#    'size': [256, 1600]},
#   'bbox': [881, 0, 23, 256],
#   'area': 5243,
#   'image_id': 'fe01b0ce0.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 14},
#  {'segmentation': {'counts': '[jX6f0d6f00O1000000O01000O1000000O10000O10O1000O10000O1000000O10O10O1000000O10000O10O1000O10000O1000000O10O10O1000000O1000000O10O10O1000000O10000O1000O10O10000O1000000O1000O01000000O10000O1000O10O10000O1000000O1000O01000000O10000O100000O0100M3K5J6KknX5',
#    'size': [256, 1600]},
#   'bbox': [803, 42, 121, 55],
#   'area': 3856,
#   'image_id': '9ebb54e56.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 15},
#  {'segmentation': {'counts': 'bQ`33h75L4M4O000O101O000O101O00000O2O00000O2O00000O2O0000000O2O00000O2O0000001N1000001N1000001O0O10001O0O10001O000O3N2N2N2M3N2N2N1N3N2N2N2N2M3N1O2N2M3N2N2M3N2M2O2M3M3N2M3N2M2N3N2M3N2M3gLaLl1b3fMPMT2R3^M_M\\2Y4J5J6J6K6I6K5J6J6K5J7J5J6K3MO1N2N1O2N2TMLkM5m1;iMGP2h0fMZOS2U1cMmNU2c1bM^N1[MUNe2S2QMnMP3Z2fLhMY3a2]LaMc3^:I8J5K7J7H7Dknc6',
#    'size': [256, 1600]},
#   'bbox': [448, 1, 304, 255],
#   'area': 29896,
#   'image_id': '9ebb54e56.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 16},
#  {'segmentation': {'counts': '..._1aNRTP9',
#    'size': [256, 1600]},
#   'bbox': [18, 1, 429, 232],
#   'area': 35835,
#   'image_id': '9ebb54e56.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 17},
#  {'segmentation': {'counts': '_c\\54`7=N2N2N2O1N1O2N1N2O1N2N3M2N2O100O101N100O100O101O0000001N10001O0001N3N2N2M4A]I[Og6=d0I7HRmh6',
#    'size': [256, 1600]},
#   'bbox': [690, 76, 42, 50],
#   'area': 1513,
#   'image_id': '012a9a4c7.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 18},
#  {'segmentation': {'counts': ']h_51h78N2N1O2O1N2N1O2O1O2N2N1O1O2N1O1O1O2N1O1O2N100O1001O1N3M2N2N2N2N2N5K5K3L3L5Ll^f6',
#    'size': [256, 1600]},
#   'bbox': [703, 0, 39, 43],
#   'area': 963,
#   'image_id': '012a9a4c7.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 19},
#  {'segmentation': {'counts': 'dVc67]7<G9K6K4K5M3N2O2N1N2O1N2O2N1N2O10001O0O1000001O0000000O101O000000000O10001O0000000O1000001O0000000O10000011N3M4L3K5I7I8I6I7I7J7H7ISZ\\5',
#    'size': [256, 1600]},
#   'bbox': [844, 155, 66, 73],
#   'area': 3758,
#   'image_id': '447d8ce19.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 20},
#  {'segmentation': {'counts': '[lR58Z7?@`0@`0A?G9O1O1O1O100O1O1O1O001O1O100O1O1O1O1?An0RO>BO1O8G<E6J6J7I6J6I5L000000000O10000000O10O10000000000000N3M2M3N2M3N2M6K7H8H8H8H8G9H8H8Hbjk6',
#    'size': [256, 1600]},
#   'bbox': [651, 73, 69, 153],
#   'area': 5046,
#   'image_id': '447d8ce19.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 21},
#  {'segmentation': {'counts': 'RXS5;e7e0[Oe0[Oe0[Oe0[Oe0\\Od0[Oe0[Oe0[Oe0[Oe0[Oe0[O;E000001O000000009Ga0_O`0@a0_Oa0_O`0@a0_Oa0_O`0@a0_Oa0_O`0@a0_Oa0_O`0@Z`S7',
#    'size': [256, 1600]},
#   'bbox': [653, 2, 36, 253],
#   'area': 5655,
#   'image_id': 'eb5d79866.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 22},
#  {'segmentation': {'counts': 'Vjb1V1e5V1O1O1O1O1O10O01POeMYL\\2f3nMPLS2Y3nM]L90j1a2nN_MR2^1PObNQ1<0DV40000000000000000000000O1000000000000000N2M3N2M3M3M3M3N6I;E;E6K3L3M4L3M3N3L3M3M4M2M4L3M3N3L3M4L3MU1lNV2iMmk\\:',
#    'size': [256, 1600]},
#   'bbox': [203, 2, 65, 252],
#   'area': 12247,
#   'image_id': 'eb5d79866.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 23},
#  {'segmentation': {'counts': 'S][4Q1n4Q2oMQ2oNQ1000000000000000000000001O00000000000000000GSJ_Nm5S1aJmN_5d0PK\\OP56^KJ\\600000000000000000000000000000000000QX5ogc7',
#    'size': [256, 1600]},
#   'bbox': [557, 0, 68, 256],
#   'area': 15547,
#   'image_id': 'eb5d79866.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 24},
#  {'segmentation': {'counts': 'Y_b5:d7;F3M3N0O100O100O10000000000000000000000000000001O1O2N1O1N10001O01O000AEZI:d6b0O1O100000000000O101O001N2O001N1C_I[Oa6d0>O101N1O1O1N5HWQ^6',
#    'size': [256, 1600]},
#   'bbox': [713, 214, 62, 42],
#   'area': 1802,
#   'image_id': 'eb5d79866.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 25},
#  {'segmentation': {'counts': 'P`Y9P1P7P2PNP2PNP2PNPa3PgQ3',
#    'size': [256, 1600]},
#   'bbox': [1190, 0, 19, 256],
#   'area': 4352,
#   'image_id': '91fc61e33.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 26},
#  {'segmentation': {'counts': 'PXk8P1P7P2PNP2PNP2PNoh1QOPXN00000O1000000O10P`_3',
#    'size': [256, 1600]},
#   'bbox': [1133, 0, 21, 256],
#   'area': 4846,
#   'image_id': '91fc61e33.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 27},
#  {'segmentation': {'counts': '19g7b0^Oa0_...`0@<n5CUJ:l5FUJ8l5HUJ6l5JUJ4l5LUJ2l5MVJ1k5OUJ0l50UJNl52TJMm53TJKm54UJJl56TJIm57TJGm59m0O10000O100O100O1N2N2N2O3L5KjW]9',
#    'size': [256, 1600]},
#   'bbox': [0, 1, 395, 148],
#   'area': 37217,
#   'image_id': 'c7a4a7472.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 28},
#  {'segmentation': {'counts': ']oh;a0_6P1POP1POQ1\\Oc0L4N201O0000000000O1O1O1O1N[1eN<D;E<DXba0',
#    'size': [256, 1600]},
#   'bbox': [1507, 116, 22, 140],
#   'area': 2488,
#   'image_id': '1561eb657.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 29},
#  {'segmentation': {'counts': 'fga;7]7<D<C=D<D<C=D<D<C=D<C=D<D<C=D9G8G8I6J7N24J6I7I7I7H;C>B>lNT1I7J6I7J6I7D<^Ob0_Oi0VOTod0',
#    'size': [256, 1600]},
#   'bbox': [1478, 0, 38, 253],
#   'area': 4793,
#   'image_id': '1561eb657.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 30},
#  {'segmentation': {'counts': 'nR:5k7:F9G9G:F9G5K0000000000000O10O10000000000000000H8B>B>Bamn;',
#    'size': [256, 1600]},
#   'bbox': [40, 93, 28, 58],
#   'area': 1311,
#   'image_id': 'ab70f8ba6.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 31},
#  {'segmentation': {'counts': 'PVb8P2Q2o3PNP20000000000000000000000000000000O10000000000PNP2RLmcg3',
#    'size': [256, 1600]},
#   'bbox': [1096, 1, 26, 255],
#   'area': 6113,
#   'image_id': 'ab70f8ba6.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 32},
#  {'segmentation': {'counts': 'Ph^:Y1g6b2^Mb2^MY1gN0000000000O100000000000000000i0VOa1`Na1_Na1_N`1`NUQk1',
#    'size': [256, 1600]},
#   'bbox': [1339, 0, 24, 246],
#   'area': 4905,
#   'image_id': 'ab70f8ba6.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 33},
#  {'segmentation': {'counts': 'PPl9P2P6P4PLoi2QNPXM000000f0ZOZ1fNZ1fN[1eNZ1fNZ1fNgh]2',
#    'size': [256, 1600]},
#   'bbox': [1264, 0, 24, 256],
#   'area': 5112,
#   'image_id': 'ab70f8ba6.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 34},
#  {'segmentation': {'counts': 'o\\R6f1P3Y3\\Nd11O100O1O1O1O1O1Ob0^OR1oNQ1nNR1nNR1nNR1nN[ZY6',
#    'size': [256, 1600]},
#   'bbox': [777, 0, 17, 213],
#   'area': 2694,
#   'image_id': '648e67d1b.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 35},
#  {'segmentation': {'counts': 'Pdl9P2P6P2PN0000000000O1000000O1000000OP2QNQR_2',
#    'size': [256, 1600]},
#   'bbox': [1266, 128, 17, 128],
#   'area': 2031,
#   'image_id': 'e8340339d.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 36},
#  {'segmentation': {'counts': 'P\\f4f0Z7Z1fNZ1fNf0ZO0O100000000000000O100000000Q2oMQjd7',
#    'size': [256, 1600]},
#   'bbox': [601, 126, 19, 130],
#   'area': 2195,
#   'image_id': 'e8340339d.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 37},
#  {'segmentation': {'counts': 'mkZ9a0_7P1POQ1oNP1POa0_O0000000000000000000R2nMQRQ3',
#    'size': [256, 1600]},
#   'bbox': [1195, 125, 16, 131],
#   'area': 1768,
#   'image_id': 'e8340339d.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 38},
#  {'segmentation': {'counts': '\\c`6?a7n0ROm0SOm0SOn0RO?A000000000O10000000000000O1000Z2fM[ji5',
#    'size': [256, 1600]},
#   'bbox': [834, 107, 22, 149],
#   'area': 2819,
#   'image_id': 'e8340339d.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 39},
#  {'segmentation': {'counts': '',
#    'size': [256, 1600]},
#   'bbox': [1172, 0, 160, 101],
#   'area': 2980,
#   'image_id': 'e8340339d.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 40},
#  {'segmentation': {'counts': 'kj_\\6KeI4[6KhI3X6MiI2W6NjI0W60kINU62lIMT63mILS64oIJQ65QJIP67RJGn59SJFn59SJFm5:UJDk5<VJBk5>WJ@i5?YJ@g5`0l00000000000O1000001O1O1O1N2O1O1O1O1O1O1N2O1OQ`b4',
#    'size': [256, 1600]},
#   'bbox': [831, 0, 183, 115],
#   'area': 5938,
#   'image_id': 'e8340339d.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 41},
#  {'segmentation': {'counts': '...',
#    'size': [256, 1600]},
#   'bbox': [595, 0, 229, 107],
#   'area': 7780,
#   'image_id': 'e8340339d.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 42},
#  {'segmentation': {'counts': 'TXc4e0[7Z1fNZ1fNZ1fNZ1fNZ1fNe0[O0000000000000000000000000000000000000P1POo1QNn1RNo1QNPQe7',
#    'size': [256, 1600]},
#   'bbox': [589, 4, 30, 252],
#   'area': 6300,
#   'image_id': '37009c774.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 43},
#  {'segmentation': {'counts': 'PP\\13m74L4L4L4L4L4L4L4L4L[1eN1O001O001O001O1O001O001O001O1O001O001O001O2N2N2N2N2N2N2N1O2N2N2N2N2N2N2N2N2N2N2N2N2N2N001O0000001O00001O0000001O00001O0000001O0000001O00001O0000001O0fMdKP1\\4kNQLm0P4lN^Ll0b3oNkLi0U3ROXMf0h2TOcMg0^2SOiMk0h4N3M2N2N2N3M2N2N3M2N2N2NQ`3OP`L000000000000000000000000000000000O1000000000000000000O1000000cLOkN1S13iNOV14eNOY15aNO]15^NNa18WNKg1=PNFo1a0gMCW2e0`M^O_2i0XMZOf2n0QMUOn2R1iLQOU3W1aLmN]3[1ZLhNe3j2N2O1N2O1O1N2O1O1N2O1O1N2O1O1N2O1O1N2O100O100O1O100O1O100O100O1O100O100O100O1O100O100O1O100O100O100O1O100O100O1O100O100O100O1O100O100O1N2N2N2N2N2N2N2N2N2N2N2N2N2N2N2N2N2N2N2N2N2N2N2N2O1N2O1N2N2O1NRXR9',
#    'size': [256, 1600]},
#   'bbox': [176, 0, 263, 256],
#   'area': 35023,
#   'image_id': '37009c774.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 44},
#  {'segmentation': {'counts': '_PP4m5R2o0POa0@1O1O1N2O2N1O1N2O1O1000001O000000000000001O000000000000001O000000000000001O000000000000000000000000001O000000000000000000000000000000000000000000Phg00PXXO00000O1000000O1000000O1000000O1000000O1000000O1000000O2O0J6F:F;D;F:E;F;E:F:G9G:F9G9G9F;F9G9G9G:F9SOghh6',
#    'size': [256, 1600]},
#   'bbox': [512, 0, 221, 256],
#   'area': 53600,
#   'image_id': 'b20fcab43.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 45},
#  {'segmentation': {'counts': 'Phd8P4P4Pl0QLoWO0000000000000000001O000000000C=WOi0VOj0WOi0WOj0VOi0WOi0VOj0WOi0WOfhc3',
#    'size': [256, 1600]},
#   'bbox': [1107, 0, 30, 256],
#   'area': 6241,
#   'image_id': '1435cd970.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 46},
#  {'segmentation': {'counts': 'PPZ8j0V7c1]Nc1]Nc1^Nb1]Nj0VO0000000001O0000000000001O00000QLlcP4',
#    'size': [256, 1600]},
#   'bbox': [1064, 0, 22, 256],
#   'area': 4832,
#   'image_id': '1435cd970.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 47},
#  {'segmentation': {'counts': 'PPl7P1P7P2PNP2PNP2PNP]4P[^4',
#    'size': [256, 1600]},
#   'bbox': [1008, 0, 23, 256],
#   'area': 5248,
#   'image_id': '1435cd970.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 48},
#  {'segmentation': {'counts': 'PX[6`0`7n0ROo0QOn0SOn0QOn0ROo0QOn0RO`0@0001O0000000000001O000000Y1gN`2`M`2`MdYn5',
#    'size': [256, 1600]},
#   'bbox': [813, 0, 25, 245],
#   'area': 4740,
#   'image_id': '1435cd970.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 49},
#  {'segmentation': {'counts': 'ShT:d0\\7X1hNW1iNX1hNW1iNX1hNd0\\O1O1O1O001O1O1OQOo0SNm1TNl1SNjiV2',
#    'size': [256, 1600]},
#   'bbox': [1299, 3, 18, 244],
#   'area': 3130,
#   'image_id': '8e49af649.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 50},
#  {'segmentation': {'counts': 'QXl;a0_7P1POQ1oNQ1oNP1POa0_O0000O2O000000000O1000n_?',
#    'size': [256, 1600]},
#   'bbox': [1521, 1, 17, 164],
#   'area': 2358,
#   'image_id': '8e49af649.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 51},
#  {'segmentation': {'counts': 'Th]:b0^7R1nNR1mNT1mNR1nNR1nNR1nNb0^O0O100000000O10000i0WO`1`Na1_Na1_N`1`NTal1',
#    'size': [256, 1600]},
#   'bbox': [1335, 1, 22, 244],
#   'area': 3889,
#   'image_id': '8e49af649.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 52},
#  {'segmentation': {'counts': 'PXi8P2P6P4PLoY1QNPhN00000000001O00000O100000000VOj0^Nb1]Nc1^Nb1^NaQ`3',
#    'size': [256, 1600]},
#   'bbox': [1125, 0, 27, 256],
#   'area': 5980,
#   'image_id': '8e49af649.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 53},
#  {'segmentation': {'counts': 'Phf4T2l5S2mMO1O1N2O1O1N2O1@`0QOo0POP1QOoPf7',
#    'size': [256, 1600]},
#   'bbox': [603, 0, 13, 135],
#   'area': 1365,
#   'image_id': '8e49af649.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 54},
#  {'segmentation': {'counts': 'PPW4e0[7X1hNY1gNX1hNe0[O000000000000001O0a0_OP1POQ1oNQ1oNP1PO]ST8',
#    'size': [256, 1600]},
#   'bbox': [540, 0, 19, 164],
#   'area': 2368,
#   'image_id': '8e49af649.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 55},
#  {'segmentation': {'counts': '`cP4:f71N2O1O1N2O001N2O1O1O1N10000O10000O1000O1000000000000002N1O2N1O2N1O1O2N1O2O2M6K4L5K4K6K2NN2O0O2N2O0O2N2N2O0O2N2N2N1O2M9H?A?ATco7',
#    'size': [256, 1600]},
#   'bbox': [514, 106, 63, 74],
#   'area': 2252,
#   'image_id': '3ead6a6bf.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 56},
#  {'segmentation': {'counts': 'coZ3=k6h0XOh0XOh0D<0000000000000G9@`0@`0@`0@`0@akP9',
#    'size': [256, 1600]},
#   'bbox': [427, 159, 17, 97],
#   'area': 1163,
#   'image_id': 'd98664198.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 57},
#  {'segmentation': {'counts': '`aU3h0X7^1bN^1bNg0ZON1O1O1O100O2N1O1O1O_nV9',
#    'size': [256, 1600]},
#   'bbox': [406, 48, 14, 139],
#   'area': 1676,
#   'image_id': 'd98664198.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 58},
#  {'segmentation': {'counts': 'mme39U7a0_Ob0^Oa0@a0^Oa0_Ob0_O`0_Ob0^Oa0_O;NL=D<C=C=D<C=C=D<C=C=D<C=C=DZPd8',
#    'size': [256, 1600]},
#   'bbox': [471, 2, 25, 196],
#   'area': 2287,
#   'image_id': 'd98664198.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 59},
#  {'segmentation': {'counts': 'cdj95h77K3M3M3M3M3M2M3N2N2O1O1O1bIXOa5h1L4L9G2N3M3M2N3L4M2N2N000000000O10O10000000000000000O101O0N2N2mMUKn0n4oNWKm0k4QOYKe0o4WOVKa0Q5^ORK>P5ASK<o4BSK;P5CSK:P5CSK9P5EUK6m4I]KKg42e1O1N3N1N`SV2',
#    'size': [256, 1600]},
#   'bbox': [1258, 131, 61, 106],
#   'area': 4098,
#   'image_id': 'd98664198.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 60},
#  {'segmentation': {'counts': 'hcW9k0T7101N100O2N100O101N10001O00001O0000000000002N2N2O1O0000O100O100O100O0O2O1O1O001O1O1O001O1O1O2N1O1O2M3M3L4M3M7IX[j2',
#    'size': [256, 1600]},
#   'bbox': [1182, 114, 56, 51],
#   'area': 1921,
#   'image_id': 'd98664198.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 61},
#  {'segmentation': {'counts': 'Rki;4f79G9[IGW5f1K5N2N2M3N2N1O0O2O001O0010O0001O001O010O00O1N2N2N3M2K5J7I7I7L3O2N2N2O1N3M3M2N3M3G9B\\m:',
#    'size': [256, 1600]},
#   'bbox': [1511, 75, 45, 89],
#   'area': 2860,
#   'image_id': 'd98664198.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 62},
#  {'segmentation': {'counts': 'PXh7[1e61O1O1O1O1O001O1O1O1O1O1O1O1O1O001O1O1O1O1OO1O1O1O1O1O1O1O1O1O7I=C=C=Cgf^4',
#    'size': [256, 1600]},
#   'bbox': [993, 0, 36, 62],
#   'area': 1822,
#   'image_id': '918c32419.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 63},
#  {'segmentation': {'counts': 'Phh5[1e6e2[Me2[M[a4[OZ_KZ1fN[1eNZ1fN[1eNZ1fNfP`6',
#    'size': [256, 1600]},
#   'bbox': [739, 0, 28, 256],
#   'area': 6016,
#   'image_id': '918c32419.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 64},
#  {'segmentation': {'counts': 'e^[8[1P4e2[MkQ5_OhoJc1]Nc1]Nc1]NcQn3',
#    'size': [256, 1600]},
#   'bbox': [1069, 0, 27, 256],
#   'area': 5888,
#   'image_id': 'bff7d63af.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 65},
#  {'segmentation': {'counts': 'PPd7P4P4Pd8QLo_G000I7B>B>B>B>C=B>B>B>J6O10000O1000000O10000O10000O1000000O10000O100QOo0RNmQZ4',
#    'size': [256, 1600]},
#   'bbox': [976, 0, 72, 256],
#   'area': 14383,
#   'image_id': 'bff7d63af.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 66},
#  {'segmentation': {'counts': 'X_R23h75K5K5M300001O0000010O0000001O0000001O0N2M3N3L3M3NWQW:',
#    'size': [256, 1600]},
#   'bbox': [265, 214, 26, 22],
#   'area': 413,
#   'image_id': '3704cdfd6.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 67},
#  {'segmentation': {'counts': 'bfY17i7>C=B7JO001O0010O01O001O001O001O010O001O001O001O010O6J:F:FWhn:',
#    'size': [256, 1600]},
#   'bbox': [166, 210, 30, 45],
#   'area': 981,
#   'image_id': '3704cdfd6.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 68},
#  {'segmentation': {'counts': '_nj2X1h600000001O000000000000001O00000000c0]OlX`9',
#    'size': [256, 1600]},
#   'bbox': [363, 207, 19, 40],
#   'area': 721,
#   'image_id': '3704cdfd6.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 69},
#  {'segmentation': {'counts': 'gnP38Y7?H8000001O00000001O00000001O0008H`0@WYZ9',
#    'size': [256, 1600]},
#   'bbox': [387, 192, 19, 33],
#   'area': 536,
#   'image_id': '3704cdfd6.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 70},
#  {'segmentation': {'counts': 'lmm13g76J6J6J6M300000000000000000000000L4I7H8IVk\\:',
#    'size': [256, 1600]},
#   'bbox': [247, 161, 21, 30],
#   'area': 495,
#   'image_id': '3704cdfd6.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 71},
#  {'segmentation': {'counts': 'dlZ2e1[6000000000000000000000000L4H8I7H8I7I7HdSP:',
#    'size': [256, 1600]},
#   'bbox': [299, 148, 20, 53],
#   'area': 874,
#   'image_id': '3704cdfd6.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 72},
#  {'segmentation': {'counts': 'ima12j74M3L5K4M3L4M4K4L4M3L5M2000001O000000001O0000001O0000001O000009H`0_Oa0_OVZe:',
#    'size': [256, 1600]},
#   'bbox': [199, 143, 35, 52],
#   'area': 1338,
#   'image_id': '3704cdfd6.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 73},
#  {'segmentation': {'counts': 'j^^24e79G8I8G9G8K6N1O2N1N01O1O100O1O1O1O001OjNSO[Km0e4V11O1O1K5H8K5N2N2N2N2N2O2M2N2N2N2M3K5K5K5J6K5K5K5KiSf9',
#    'size': [256, 1600]},
#   'bbox': [313, 139, 46, 97],
#   'area': 2209,
#   'image_id': '3704cdfd6.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 74},
#  {'segmentation': {'counts': '[]o04f77I6J7I6M4O0O2O1O001N101O001N01O1O1O0O2O1O1O0011O0O2O001O0O2O1O001N101O001N101O1O0O2O0a0@2M2O2M3M2N3M3M2M3N3M2N2N2NYRR;',
#    'size': [256, 1600]},
#   'bbox': [125, 134, 58, 52],
#   'area': 1892,
#   'image_id': '3704cdfd6.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 75},
#  {'segmentation': {'counts': 'l[c14e77H8I7I7L3100000000000000O1000O1000000000O1000000^OhUf:',
#    'size': [256, 1600]},
#   'bbox': [205, 90, 26, 38],
#   'area': 823,
#   'image_id': '3704cdfd6.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 76},
#  {'segmentation': {'counts': 'VSo13h75J6K5K5K5J6K5M30000000000000000O10M3J6K5K5J6K5K5JY^Z:',
#    'size': [256, 1600]},
#   'bbox': [252, 61, 26, 44],
#   'area': 779,
#   'image_id': '3704cdfd6.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 77},
#  {'segmentation': {'counts': 'biP17i7=C<D=C7I0000001O00000000001O0000L4H8I7H8H8I7HfVY;',
#    'size': [256, 1600]},
#   'bbox': [131, 50, 24, 54],
#   'area': 981,
#   'image_id': '3704cdfd6.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 78},
#  {'segmentation': {'counts': 'ePc14f76J7I6M301O0000001O00001O00001O00O1N2N2N2N2N2N2N2N2N2N2N2N2N2NRPe:',
#    'size': [256, 1600]},
#   'bbox': [204, 0, 32, 30],
#   'area': 644,
#   'image_id': '3704cdfd6.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 79},
#  {'segmentation': {'counts': 'oXX12j74M3L4M3L4M3L4N20000O1000O1000O1000000O100000000OK6F:FZhP;',
#    'size': [256, 1600]},
#   'bbox': [161, 0, 28, 33],
#   'area': 673,
#   'image_id': '3704cdfd6.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 80},
#  {'segmentation': {'counts': 'YRY68^7`0cHYOo6P1I6K5A`0M2N2O1O1N2O10O1N101N3M4M2M3K6HZgQ6',
#    'size': [256, 1600]},
#   'bbox': [804, 21, 21, 70],
#   'area': 1133,
#   'image_id': 'a56d4b7be.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id':
jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 95},
#  {'segmentation': {'counts': 'iQ[82l74M2N2O1N1N3M2O2M2O1O1O100O1O1O10000N2M3N2O100O1001O0M4L3M3M4L3M4M2M4L3MPgk3',
#    'size': [256, 1600]},
#   'bbox': [1068, 30, 37, 36],
#   'area': 786,
#   'image_id': '374d9c63f.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 96},
#  {'segmentation': {'counts': '...`]7',
#    'size': [256, 1600]},
#   'bbox': [364, 0, 285, 253],
#   'area': 36427,
#   'image_id': '3933a5fcc.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 97},
#  {'segmentation': {'counts': 'kod34d78H8H8L4000000000O1000001O000000000K5F:FZie8',
#    'size': [256, 1600]},
#   'bbox': [467, 223, 21, 32],
#   'area': 543,
#   'image_id': '8f8a23f39.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 98},
#  {'segmentation': {'counts': 'Uf34m75J7J5J6K3L01O001OO100O0014L7I8H7IohW<',
#    'size': [256, 1600]},
#   'bbox': [14, 197, 18, 33],
#   'area': 400,
#   'image_id': '8f8a23f39.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 99},
#  {'segmentation': {'counts': 'Wmn3W1i60000O0100000O1000O1000O1000000O010000000O10O1000O10c0]OZRZ8',
#    'size': [256, 1600]},
#   'bbox': [507, 163, 28, 43],
#   'area': 1047,
#   'image_id': '8f8a23f39.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 100},
#  {'segmentation': {'counts': 'aln:8h7>B7I000000000O10O100000000000`S]1',
#    'size': [256, 1600]},
#   'bbox': [1403, 144, 16, 30],
#   'area': 437,
#   'image_id': '8f8a23f39.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 101},
#  {'segmentation': {'counts': 'kaY;5k7:F9G5K00O100O100O100O100O100O100O10;Dk]Q1',
#    'size': [256, 1600]},
#   'bbox': [1446, 59, 20, 29],
#   'area': 462,
#   'image_id': '8f8a23f39.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 102},
#  {'segmentation': {'counts': '^in3:f7b0^Oc0]Ob0^Ob0^O:F0000O100000001N10000000000O100000000Og0ZO\\1dN_\\Z8',
#    'size': [256, 1600]},
#   'bbox': [507, 46, 27, 93],
#   'area': 2133,
#   'image_id': '8f8a23f39.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 103},
#  {'segmentation': {'counts': 'X_`Xm8',
#    'size': [256, 1600]},
#   'bbox': [265, 138, 193, 118],
#   'area': 14098,
#   'image_id': '73e1969d4.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 104},
#  {'segmentation': {'counts': '...',
#    'size': [256, 1600]},
#   'bbox': [876, 113, 260, 143],
#   'area': 25031,
#   'image_id': '73e1969d4.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 105},
#  {'segmentation': {'counts': 'fTQ38h7>',
#    'size': [256, 1600]},
#   'bbox': [388, 106, 164, 117],
#   'area': 13428,
#   'image_id': '73e1969d4.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 106},
#  {'segmentation': {'counts': '...',
#    'size': [256, 1600]},
#   'bbox': [495, 0, 329, 184],
#   'area': 46228,
#   'image_id': '73e1969d4.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id':
jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 111},
#  {'segmentation': {'counts': 'PdP9P41o3000000000000000O100000000000000000ogZ3',
#    'size': [256, 1600]},
#   'bbox': [1154, 1, 19, 255],
#   'area': 4708,
#   'image_id': '744c77e7d.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 112},
#  {'segmentation': {'counts': '\\oP:c0Y6T1lNT1kNU1lNT1lNT1lNT1]Oc00000000O1000000000000000000M3VOj0^Nb1^Nb1^Nb1^NbaX2',
#    'size': [256, 1600]},
#   'bbox': [1283, 0, 27, 255],
#   'area': 5329,
#   'image_id': '744c77e7d.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 113},
#  {'segmentation': {'counts': 'PnY5o1Q2P4RNn100000000000000O10000000O100000000000000000O1000000f0ZOZ1fN[1fJd`n6',
#    'size': [256, 1600]},
#   'bbox': [679, 0, 31, 255],
#   'area': 7282,
#   'image_id': '744c77e7d.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 114},
#  {'segmentation': {'counts': 'P``6[1e6e2[Me2[M[a3ROc_Lj0VOi0WOj0VOi0WOj0VOi0WOj0VOi0WOj0VO]Xh5',
#    'size': [256, 1600]},
#   'bbox': [834, 0, 28, 256],
#   'area': 5504,
#   'image_id': '539be6ba4.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 115},
#  {'segmentation': {'counts': '\\`h1]4c3000O2O00000O10001O000O10001O0O10I7B>C=B=D=B>^Ob0^Oa0_Ob0^O\\h`:',
#    'size': [256, 1600]},
#   'bbox': [226, 6, 27, 150],
#   'area': 3214,
#   'image_id': 'c5a41d53c.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 116},
#  {'segmentation': {'counts': 'Y_`1>h6j0UOk0VOj0UOl0UOj0VOj0UOk0VOj0B>00O2O000O10000O101O0O100^6bHS1<F:E2OK5H7I8HbPh:',
#    'size': [256, 1600]},
#   'bbox': [193, 4, 30, 250],
#   'area': 4394,
#   'image_id': 'c5a41d53c.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 117},
#  {'segmentation': {'counts': 'ln[19V7c0\\Od0]Ob0^Oc0\\Od0]Ob0^O0O@a0@`0_O`0@a0@h0WOohP;',
#    'size': [256, 1600]},
#   'bbox': [175, 3, 14, 236],
#   'area': 976,
#   'image_id': 'c5a41d53c.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 118},
#  {'segmentation': {'counts': 'heT25k79G9G9G8G:...',
#    'size': [256, 1600]},
#   'bbox': [274, 165, 204, 91],
#   'area': 14034,
#   'image_id': '622086df1.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 119},
#  {'segmentation': {'counts': 'lnj45b79G:F9G9G9G:...\\Xe1',
#    'size': [256, 1600]},
#   'bbox': [619, 152, 767, 104],
#   'area': 23737,
#   'image_id': '622086df1.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 120},
#  {'segmentation': {'counts': '\\c:',
#    'size': [256, 1600]},
#   'bbox': [75, 64, 167, 77],
#   'area': 9183,
#   'image_id': '622086df1.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 121},
#  {'segmentation': {'counts': 'RQR6o0Q70000000001O000000000000000000001O00000000000000000000001O000000000000000000001O0000000000>B\\VR6',
#    'size': [256, 1600]},
#   'bbox': [776, 34, 47, 31],
#   'area': 1347,
#   'image_id': '622086df1.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 122},
#  {'segmentation': {'counts': '^:',
#    'size': [256, 1600]},
#   'bbox': [137, 13, 126, 81],
#   'area': 4512,
#   'image_id': '622086df1.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 123},
#  {'segmentation': {'counts': 'jZf13h75UN3^K2`4f0eJ_OX5g1L3N2M3N2M3M4M2N2000O100O100O10000O10O10O100O100O1N2O1O1N2O1O1N2O1O2M2O1N2N2N2M3N2N2M3N3M2M3N2N2M3N2N2M3M3M4K4M3M3K5HUPZ:',
#    'size': [256, 1600]},
#   'bbox': [217, 0, 63, 95],
#   'area': 4141,
#   'image_id': '82d728afa.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 124},
#  {'segmentation': {'counts': 'PPf8j0V7c1]Nc1]Nc1]Nc1]Njh20VWMc1]Nc1]Nc1]Nc1]NjXd3',
#    'size': [256, 1600]},
#   'bbox': [1112, 0, 22, 256],
#   'area': 4352,
#   'image_id': '8ff35e571.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 125},
#  {'segmentation': {'counts': 'PP[8c0]7T1lNT1lNT1lNT1lNT1lNT1lNb0^O0000001O000000000j0VOc1^Nb1]Nb1^Nc1]NkXo3',
#    'size': [256, 1600]},
#   'bbox': [1068, 0, 22, 255],
#   'area': 4061,
#   'image_id': '8ff35e571.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 126},
#  {'segmentation': {'counts': 'PPS8[1e6e2[Me2[M[i2_OVWMc1]Nc1]Nc1]Nc1]NjhW4',
#    'size': [256, 1600]},
#   'bbox': [1036, 0, 20, 256],
#   'area': 4096,
#   'image_id': '8ff35e571.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 127},
#  {'segmentation': {'counts': 'aVP:;c74PODWJ?g5EkIOFa0[6n0N`0_O30O1nMnJR1P610O0O2KXIPOi6m08E:L\\i[2',
#    'size': [256, 1600]},
#   'bbox': [1280, 175, 16, 74],
#   'area': 607,
#   'image_id': 'cd3b9899c.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 128},
#  {'segmentation': {'counts': 'R[i;d0Z7`0@d0\\Oc0]Om0TOY1gN4M3L`0@1O100O1001O00001O01O01O0M[MkJf2S55M3Ng0XOh0WOi0XOh0VOV1jN`Q?',
#    'size': [256, 1600]},
#   'bbox': [1509, 84, 30, 172],
#   'area': 4008,
#   'image_id': 'cd3b9899c.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 129},
#  {'segmentation': {'counts': 'TjR:6f7=mHa1T4Z1K3NO001O5J2Og0VOa1\\Nh[Z2',
#    'size': [256, 1600]},
#   'bbox': [1291, 64, 11, 114],
#   'area': 964,
#   'image_id': 'cd3b9899c.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 130},
#  {'segmentation': {'counts': 'oek11m73M3M3N2O1O1N2O001O1O1O1O1O1O1O1OO100O1O100O1O1O100O1M3L4L4L]b\\:',
#    'size': [256, 1600]},
#   'bbox': [238, 183, 31, 24],
#   'area': 491,
#   'image_id': 'a763e8b83.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 131},
#  {'segmentation': {'counts': '[[T;3l73M1N2O1O2M2O1O1O1O2O000001O1O1N1KbHH_776N2Ko\\V1',
#    'size': [256, 1600]},
#   'bbox': [1425, 95, 21, 19],
#   'area': 265,
#   'image_id': '5727d7f96.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id':
jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 140},
#  {'segmentation': {'counts': 'SPd8o3Q4n3RL0000000O10000000000000000000000O1000000000PLoSf3',
#    'size': [256, 1600]},
#   'bbox': [1104, 1, 24, 255],
#   'area': 5842,
#   'image_id': '02b906933.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 141},
#  {'segmentation': {'counts': 'PW[3P1Q5o1PNP2QNo1POP100000000O1000000000000000PX1o3QdNPln8',
#    'size': [256, 1600]},
#   'bbox': [428, 0, 24, 256],
#   'area': 5481,
#   'image_id': '02b906933.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 142},
#  {'segmentation': {'counts': 'Phg1P2P6P4PLPi3POPVLP2PNP2PNPRc:',
#    'size': [256, 1600]},
#   'bbox': [223, 0, 21, 256],
#   'area': 4608,
#   'image_id': '0984c380f.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 143},
#  {'segmentation': {'counts': 'QlV1o32o3000000O1000000000o?0Q@00P4PLPTU;',
#    'size': [256, 1600]},
#   'bbox': [155, 0, 16, 256],
#   'area': 3821,
#   'image_id': '0984c380f.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 144},
#  {'segmentation': {'counts': 'Q`d0[1e6d2\\Md2\\M[1eN0000000O10O100000000PNP2RLncg;',
#    'size': [256, 1600]},
#   'bbox': [82, 0, 16, 255],
#   'area': 3430,
#   'image_id': '0984c380f.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 145},
#  {'segmentation': {'counts': 'PW_44j78H5K3M3M2N3N2M3N2M3N2M4M2M3N2N2N1O100O1O1O1O1O1O1O100O1O1O1O1N2O1O1O1O1N2O1O1O1O1N2O1O1O1O1N2O1O1O10000O100000000O100000000O10O1Nf0oM^J:n6E?Ah`_7',
#    'size': [256, 1600]},
#   'bbox': [572, 159, 69, 92],
#   'area': 4379,
#   'image_id': 'e1a9e7c49.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 146},
#  {'segmentation': {'counts': 'VZ_41m73N1O2O1N2O001O1O0000001O00001O1O101N100O100O2N100O1N2O0O2N101N11O2M3N2I8EmUg7',
#    'size': [256, 1600]},
#   'bbox': [573, 65, 38, 30],
#   'area': 633,
#   'image_id': 'e1a9e7c49.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 147},
#  {'segmentation': {'counts': 'dY^42l72N1O2N2N2mNF]J<d5EYJ=g5DVJ>j5CSJ?l5CQJ?o5BnI?S6BjI`0V6AgIa0Y6@dIb0\\6_OaIc0^6_O_Id0`6>00010O0010O01O010O100O00100O1O2O1N2La0^OP_h7',
#    'size': [256, 1600]},
#   'bbox': [569, 5, 37, 53],
#   'area': 1233,
#   'image_id': 'e1a9e7c49.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 148},
# ...
#    'size': [256, 1600]},
#   'bbox': [1034, 0, 340, 250],
#   'area': 56689,
#   'image_id': '4dd35625f.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 949},
#  {'segmentation': {'counts': '`\\S13g76K4K6M3000O10O1000O1000000O10O1000O10VdW;',
#    'size': [256, 1600]},
#   'bbox': [141, 122, 20, 25],
#   'area': 380,
#   'image_id': '7f30b9c64.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 950},
#  {'segmentation': {'counts': 'eRl6X1h6W1iN000000O10O10000000O10d0\\OV1jNbS`5',
#    'size': [256, 1600]},
#   'bbox': [880, 84, 15, 80],
#   'area': 1062,
#   'image_id': '7f30b9c64.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 951},
#  {'segmentation': {'counts': '`a`3=k6h0D<000001O00000000L4I7I7I7I7I7IkWk8',
#    'size': [256, 1600]},
#   'bbox': [450, 12, 17, 50],
#   'area': 622,
#   'image_id': '7f30b9c64.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id':
jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 964},
#  {'segmentation': {'counts': 'kkP31n720NV\\^9', 'size': [256, 1600]},
#   'bbox': [387, 122, 3, 3],
#   'area': 5,
#   'image_id': 'b20fb15ff.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 965},
#  {'segmentation': {'counts': 'l\\o12l72N3M2N3L3N3M2K6L3N3M2N3M2N3M2J7J5M4L3K6F9L5TOaMQLc2n3dMfKb2Y4c0O1N2O1O1O1O11O001O001O001O1O0UMgKo1Z4PNjKl1V4UNmKg1T4XNQLc1P4]NVL\\1l3bN[LV1h3iN]Lo0f3PO`Li0c3UOe201N2N1O2O1N1O2N101N2N]eQ:',
#    'size': [256, 1600]},
#   'bbox': [253, 50, 60, 119],
#   'area': 3579,
#   'image_id': 'b20fb15ff.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 966},
#  {'segmentation': {'counts': 'Tha2c0]7c0]O2N2N2N2N1O1O001O001O001O001O001O001O001O001O0000000000O10<D2M3N2M3N2N2N0O100DmHEZ7:600O101N100O101N10Q_a9',
#    'size': [256, 1600]},
#   'bbox': [327, 4, 51, 56],
#   'area': 1994,
#   'image_id': 'b20fb15ff.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 967},
#  {'segmentation': {'counts': ']^Y13k76K5J6K5K5J6K4N0O01000O10O100O001N4M5J6K4K6K7Hj`P;',
#    'size': [256, 1600]},
#   'bbox': [165, 195, 24, 45],
#   'area': 694,
#   'image_id': '25f9a8622.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 968},
#  {'segmentation': {'counts': 'Z5:S7d0]Ob0]Od0E:01O010O0000010O0000010O00000000010O00000001O001O1O1O001O1O1N101O1O1O001N2O1O2L4K5L4J6H8IPdS<',
#    'size': [256, 1600]},
#   'bbox': [0, 104, 49, 83],
#   'area': 3389,
#   'image_id': '25f9a8622.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 969},
#  {'segmentation': {'counts': 'UZV13m73NM1O02N3M2jNK_J7^51YJ4c55SJOk58lIMP6S1M3M4L3M3N3O00O1O1O100O1O1O1N2M3N2L4K5N200001O00000000000000O1000000001O001O001O1O001O001O1O1O1O1O001O1O1O1O001O0000001O000000aNUJj0j5UOWJk0i5TOYJk0g5TOZJl0f5TOZJm0e5RO\\Jn0d5QO]Jo0c5PO^JP1b5oN_JR1`5mNbJR1^5nNbJQ1_5PO`Jn0b5RO^Jl0d5TO\\Jk0e5VOZJh0h5XOXJf0j5[OVJc0k5]OUJa0m5_OSJ`0n5AQJ=Q6CoI;S6EmI7W6JhI0^60cIIc67]IDh6=WIAk6?UI_Om6b0800001O000000O100000000O10000000000O100000000O10000O1O1O1N2O1O1000000001O00000000001O00000000001O0000000010O00000001O00000000001O00000000O1000000O2O00000O10000N2N2M3NP`k9',
#    'size': [256, 1600]},
#   'bbox': [153, 0, 185, 76],
#   'area': 6627,
#   'image_id': '25f9a8622.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 970},
#  {'segmentation': {'counts': 'iWV83m73M000O100O2O0O100O01O005LXXV4',
#    'size': [256, 1600]},
#   'bbox': [1048, 244, 14, 12],
#   'area': 106,
#   'image_id': '756390c3a.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 971},
#  {'segmentation': {'counts': 'SnW85X7LUI9g6KWI8f6JYI78Fg55PJ64Ki51QJ62Nj5ORJ5N3l5JUJn0i5SOUJP1i5e0M100000O01000K[JPNe5o160OHTJ_Nl5b1VJZNk5f171O02N2O2M2N2M7I4L4M2M9G7J6I7I]jn3',
#    'size': [256, 1600]},
#   'bbox': [1055, 143, 37, 87],
#   'area': 1772,
#   'image_id': '756390c3a.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 972},
#  {'segmentation': {'counts': 'Yd`81o72M3N1N100O10OO2N2N10O3N1N3N1NQ\\k3',
#    'size': [256, 1600]},
#   'bbox': [1090, 127, 16, 16],
#   'area': 125,
#   'image_id': '756390c3a.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 973},
#  {'segmentation': {'counts': 'Qkb84j76K1O100O0103M3KPmj3',
#    'size': [256, 1600]},
#   'bbox': [1099, 92, 9, 13],
#   'area': 86,
#   'image_id': '756390c3a.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 974},
#  {'segmentation': {'counts': '_a`8Q1i6h0XO6K6K3M3MQOcJA\\53cJWO9b0S5CcJ6Q1K[40eJJ\\12Q44eJG]1OT48`JGX77:N3Lcgk3',
#    'size': [256, 1600]},
#   'bbox': [1090, 10, 15, 89],
#   'area': 630,
#   'image_id': '756390c3a.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 975},
#  {'segmentation': {'counts': 'WXi9`0^74N001OO1O1O1O1O1O2N3N2M2N3Ncob2',
#    'size': [256, 1600]},
#   'bbox': [1253, 5, 15, 21],
#   'area': 224,
#   'image_id': '756390c3a.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 976},
#  {'segmentation': {'counts': 'iWa67[7>I70000O10000000000O100000000O1000000000L3I8H8HXah5',
#    'size': [256, 1600]},
#   'bbox': [836, 224, 25, 32],
#   'area': 654,
#   'image_id': 'c63e60886.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 977},
#  {'segmentation': {'counts': 'dWo61m74L4M3L4L4M2M2N2M3L4L4N2O100O1O100O1O100O1O100O1O100O1O100O1O100OL4I8K4O3M3M4M2M3M4L3M3N2M4L3M[iT5',
#    'size': [256, 1600]},
#   'bbox': [892, 201, 48, 55],
#   'area': 1536,
#   'image_id': 'c63e60886.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 978},
#  {'segmentation': {'counts': 'nmc65c78H8H8K5000O1000000000000000000O100000000J6F:FYSf5',
#    'size': [256, 1600]},
#   'bbox': [847, 161, 24, 34],
#   'area': 674,
#   'image_id': 'c63e60886.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 979},
#  {'segmentation': {'counts': 'kdY65k78H8H9G8H8H5K00000000O10003M4L4L4L4L4L4L4K5L4L4L4Lfio5',
#    'size': [256, 1600]},
#   'bbox': [806, 155, 26, 51],
#   'area': 853,
#   'image_id': 'c63e60886.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 980},
#  {'segmentation': {'counts': '`Sj62n74L4M3L3M4L4L4M2M4L4L4L2OO000000001O000O10001O00002N2N2N3M2N3M2N2N3L3N2N3M2N3M2N2NV[[5',
#    'size': [256, 1600]},
#   'bbox': [872, 112, 42, 46],
#   'area': 1169,
#   'image_id': 'c63e60886.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 981},
#  {'segmentation': {'counts': 'Y]Z77]7<C=D<C=D<I7000O10000000000000000000000000000O100000000000U1kNgkm4',
#    'size': [256, 1600]},
#   'bbox': [937, 100, 31, 76],
#   'area': 2060,
#   'image_id': 'c63e60886.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 982},
#  {'segmentation': {'counts': 'PPg6R1n6001O0000001O0000001O0000001O0000001O0000001O0000001O00J6F:O1]OjHg0R7;E6J000000000000000000001O00000000000000000i_[5',
#    'size': [256, 1600]},
#   'bbox': [860, 0, 54, 53],
#   'area': 2161,
#   'image_id': 'c63e60886.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 983},
#  {'segmentation': {'counts': 'mTe42k74M2M4M2010O01O10O01O0010O000010O0001O00001O01O01O001N1N2N3L3NVkb7',
#    'size': [256, 1600]},
#   'bbox': [596, 147, 32, 21],
#   'area': 415,
#   'image_id': 'c63e60886.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 984},
#  {'segmentation': {'counts': 'PUT41o72M3N2M2O2N1N3N2M2O2N1N3N1N100O1O1O100O1O1O1O1O100O1O1O11O001N2N101N5K7I7I4L2O2M2N2NfRQ8',
#    'size': [256, 1600]},
#   'bbox': [528, 143, 43, 39],
#   'area': 1000,
#   'image_id': 'c63e60886.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 985},
#  {'segmentation': {'counts': 'Wl^52n72N2N3M2N2N2N001O00001O000O101O00001O0000001O0000000010O0000001O01O000001O01O0001O0001O0001O01O00010O000010O0001O00O2O0O100O2O0O1N7G`[`6',
#    'size': [256, 1600]},
#   'bbox': [699, 134, 67, 29],
#   'area': 1233,
#   'image_id': 'c63e60886.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 986},
#  {'segmentation': {'counts': 'YTa8:f71N2O1N2O2M2O1N2O1N2O0M3K5J6K5M300000O010000000000O1000O1O1O1O001O1O1N2N2N1O2N2N2N2O010O1000000O010000000O10O100000O10O1000O10000O001O1N2O1O1N2N2N2N2M3N2M3N2NmlZ3',
#    'size': [256, 1600]},
#   'bbox': [1092, 101, 80, 57],
#   'area': 2423,
#   'image_id': 'c63e60886.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 987},
#  {'segmentation': {'counts': 'mV^^OUIOk61VIOh63XILh64YIKg65ZIKe65\\IJd66]IJb66`IH_6:aIF^6:cIE]6;dIE[6;fIDZ6<gIBY6?hI_OY6b0gI[O[6e0fIYO[6g0?000O101O00000000010O0000000000001O0001O00000001O00000001O01O000000000000010O0000000000000000010O0000000001O000010O0001O00001O01O01O0001O01O00010O00001O01O01O00010O00001O01O01O00010O0000010O000N3M2N5K6JUYl0',
#    'size': [256, 1600]},
#   'bbox': [1208, 194, 278, 50],
#   'area': 6968,
#   'image_id': 'e66eb3d68.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 988},
#  {'segmentation': {'counts': 'e]T<3k74L5K5J5L5K4L4L4L3O2N1O2N1O1O2N101N1O001O001N1N3L3N2M4L3N3L3N3M23N5K4K5L5K4L4L5J5L4L5C<^OS:',
#    'size': [256, 1600]},
#   'bbox': [1553, 140, 45, 91],
#   'area': 2238,
#   'image_id': 'e66eb3d68.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 989},
#  {'segmentation': {'counts': '...',
#    'size': [256, 1600]},
#   'bbox': [1235, 101, 236, 63],
#   'area': 6992,
#   'image_id': 'e66eb3d68.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 990},
#  {'segmentation': {'counts': '...',
#    'size': [256, 1600]},
#   'bbox': [1141, 31, 327, 78],
#   'area': 10294,
#   'image_id': 'e66eb3d68.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 991},
#  {'segmentation': {'counts': 'YkQ<d0V6V1]Oc000001O000000_NgM[MY2e2lMVMT2j2QNRMn1n2WNmLi1S3\\NhLd1X3aNcL_1]3fN^LZ1b3kNZLT1f3QOULm0m3XOnKe0U4_14kNYLnMj3S2Q11O1O1O1O1O1O1O1OO2N100O1O1O1O100O1YNeJh0\\5VOnJa0S5]OWK:j4D`K4`4JjKMW42RLEo39m1N2N2O1N2N2N2NQP1',
#    'size': [256, 1600]},
#   'bbox': [1543, 0, 53, 125],
#   'area': 3666,
#   'image_id': 'e66eb3d68.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 992},
#  {'segmentation': {'counts': 'eYV<a0^720N\\n8', 'size': [256, 1600]},
#   'bbox': [1561, 52, 3, 19],
#   'area': 53,
#   'image_id': 'e66eb3d68.jpg',
#   'category_id': 1,
#   'iscrowd': 0,
#   'id': 993},
#  {'segmentation': {'counts': 'ie\\43g76J6J7I6M30001O0000001O01O0001O0000G9@a[n7',
#    'size': [256, 1600]},
#   'bbox': [562, 158, 20, 34],
#   'area': 528,
#   'image_id': '86063fcba.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 994},
#  {'segmentation': {'counts': 'cZh38h7>B>B8H00001O00000010O00000001O0000001O0006J<E;D<DRTa8',
#    'size': [256, 1600]},
#   'bbox': [481, 83, 26, 49],
#   'area': 1024,
#   'image_id': '86063fcba.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 995},
#  {'segmentation': {'counts': '^Z`3l1T6001O01O01O00001O010O00001O00010O00@`0QO^fj8',
#    'size': [256, 1600]},
#   'bbox': [449, 78, 20, 66],
#   'area': 1173,
#   'image_id': '86063fcba.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 996},
#  {'segmentation': {'counts': '_ja49W7`0G90000001O0000000001O0001O0000005K8H8H8H[eh7',
#    'size': [256, 1600]},
#   'bbox': [583, 54, 22, 35],
#   'area': 633,
#   'image_id': '86063fcba.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 997},
#  {'segmentation': {'counts': 'V[o2<n6f0ZOf0E;0001N1000000O1000001N1000000O1000001N100c0]OU1kNnTZ9',
#    'size': [256, 1600]},
#   'bbox': [381, 42, 26, 75],
#   'area': 1667,
#   'image_id': '86063fcba.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 998},
#  {'segmentation': {'counts': 'i`d3T1l60000000000000000000000001O000000000000000000000000]Ojgd8',
#    'size': [256, 1600]},
#   'bbox': [466, 25, 27, 37],
#   'area': 967,
#   'image_id': '86063fcba.jpg',
#   'category_id': 2,
#   'iscrowd': 0,
#   'id': 999},
#  ...]

# %% [markdown]
# Exportar el fichero json

# %%
with open('/data/lmp/code/siamese-mask-rcnn/data/severstal-steel-defect-detection/annotations/instances_valtest3vAll.json.json', 'w', encoding='utf-8') as f:
    json.dump(g_json, f, indent=4)

# %% [markdown]
# ## Comprobación de que se ha generado correctamente el fichero

# %%
from pycocotools.coco import COCO
import matplotlib.pyplot as plt
from pathlib import Path
from PIL import Image

# %%
coco = COCO("/data/lmp/code/siamese-mask-rcnn/data/severstal-steel-defect-detection/annotations/instances_valtest3vAll.json")
# Out:
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!

# %%
imgIds = coco.getImgIds()

# %%
dataDir=Path('/data/lmp/code/siamese-mask-rcnn/data/severstal-steel-defect-detection/valtest3vAll')

# %%
imgs = coco.loadImgs(imgIds[-3:])
_,axs = plt.subplots(len(imgs),2,figsize=(40,15 * len(imgs)))
for img, ax in zip(imgs, axs):
    I = Image.open(dataDir/img['file_name'])
    annIds = coco.getAnnIds(imgIds=[img['id']])
    anns = coco.loadAnns(annIds)
    ax[0].imshow(I)
    ax[1].imshow(I)
    plt.sca(ax[1])
    coco.showAnns(anns, draw_bbox=True)
